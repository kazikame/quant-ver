# %%
import numpy as np

# x = np.array([0, 1, 10, 100, 1000], dtype=float)
# y_p2_t3_i2 = np.array([1.5, 1.708, 2.291, 2.473, 2.491])
# y_p2_t3_i2_var = np.array([1.5, 2, 2.7265625, 2.9609375, 2.9921875])

# y_p3_t3_i2 = np.array([1.0, 1.496, 1.8299, 1.976, 1.994])
# y_p3_t3_i2_var = np.array([1.0, 1.496, 2.578125, 2.578125, 2.578125])

# # TODO: add ratios when context switch cost can vary from 0-10
# # TODO: add P = 2 T = 4

# %%
# CS_k = [0, 0.1, 0.3, 0.7, 1, 5, 10, 20, 50, 100]
# P2T3I2 = [1.5, 1.5341796875, 1.591796875, 1.691875, 1.7738671875, 2.192578125, 2.291015625, 2.3857421875, 2.451171875, 2.474609375]
# P2T3I3 = [1.5, 1.55, 1.625, 1.765, 1.863164, 2.4658203125, 2.6796875, 2.8212890625, 2.9228515625, 2.9609375]
# P3T3I2 = [1, 1.0625, 1.18, 1.375, 1.49, 1.828, 1.86, 1.9, 1.96, 1.97]

CS_k = np.array([0, 0.1, 0.3, 0.5, 1, 2, 5, 10, 20, 50, 100])/10
P2T3I6 = [1.5, 1.5625, 1.6953125, 1.7998046875, 2.0, 2.3994140625, 3.0, 3.3330078125, 3.541015625, 3.7958984375, 3.8935546875]
P2T3I7 = [1.5, 1.6, 1.75, 1.875, 2.25, 2.75, 3.5, 3.75, 3.875, 3.9375, 3.96875]
P3T4I6 = [1.666666, 1.6767578125, 1.6962890625, 1.7998046875, 2.0, 2.25, 2.5712890625, 2.7265625, 2.75, 2.75, 2.75]
P3T4I7 = [1.666666, 1.69, 1.75, 1.9, 2.1, 2.39, 2.9, 3.25, 3.29, 3.32, 3.35]

# unequal_CS_k = [0, 0.1, 0.3, 0.5, 1, 10, 100]
# unequal_P2T3I2 = [1.5, 1.535, 1.6, 1.664, 2, 8, 68]

tasks = [1, 2, 3, 4, 5, 6, 7]
fixedP2T3K100 = [1, 1, 1.8994140625, 2.7265625, 3.3330078125, 3.89404296875, 4.45]
fixedP3T4K100 = [1, 1, 1, 2.63, 2.699951171875, 2.75, 2.81]

cs = [1.1, 1.2, 1.5, 2, 4, 8]
vP2T3I4K100 = [2.8905410766601562, 3.054443359375, 3.5453948974609375, 4.363395690917969, 7.851417541503906, 14.620506286621094]
vP2T3I5K100 = [3.5582351684570312, 3.7833175659179688, 4.4925537109375, 5.9049835205078125, 11.178558349609375, 20.19318389892578]
vP2T3I6K100 = [4.1707916259765625, 4.446479797363281, 5.259193420410156, 6.573432922363281, 11.378715515136719, 20.39318389892578]
vP2T3I7K100 = [0, 0, 0, 7.1875, 14.1484375, 25.0853271484375]

vP3T4I5K100 = [2.779510498046875, 2.8595733642578125, 3.099761962890625, 3.4993209838867188, 5.099822998046875, 8.29931640625]
vP3T4I6K100 = [2.9199981689453125, 3.0899429321289062, 3.5997772216796875, 4.449501037597656, 7.892204284667969, 14.620506286621094]
vP3T4I7K100 = [3.513671875, 3.70703125, 4.48046875, 5.9049835205078125,  11.178558349609375, 20.19318389892578]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['text.usetex'] = False
sns.color_palette('pastel')
sns.set_style('darkgrid') # darkgrid, white grid, dark, white and ticks
plt.rc('axes', titlesize=18)     # fontsize of the axes title
plt.rc('axes', labelsize=18)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=13)    # fontsize of the tick labels
plt.rc('ytick', labelsize=13)    # fontsize of the tick labels
plt.rc('legend', fontsize=13)    # legend fontsize
plt.rc('font', size=14)          # controls default text sizes

fig = plt.figure(tight_layout=True, figsize=(10, 5))
ax = fig.add_subplot(1, 1, 1)


# line = ax.plot(CS_k, P2T3I7, label='#CPU=2, #Tasks=7')
# line = ax.plot(CS_k, P2T3I6, label='#CPU=2, #Tasks=6')
# line = ax.plot(CS_k, P3T4I7, label='#CPU=3, #Tasks=7')
# line = ax.plot(CS_k, P3T4I6, label='#CPU=3, #Tasks=6')
# ax.set_xlabel(r'k')

line = ax.plot(tasks[2:], fixedP2T3K100[2:], 'o--', color="orange", label='#CPU=2')
line = ax.plot(tasks[:3], fixedP2T3K100[:2] + [1,], 'o--', color="orange")
line = ax.plot(tasks[3:], fixedP3T4K100[3:], '+--', color="blue", label='#CPU=3')
line = ax.plot(tasks[:4], fixedP3T4K100[:3] + [1,], '+--', color="blue")
ax.set_xlabel(r'Tasks')
ax.xaxis.get_major_locator().set_params(integer=True)

# line, = ax.plot(cs, vP2T3I6K100, label='#CPU=2, #Task=6')
# line, = ax.plot(cs, vP2T3I5K100, label='#CPU=2, #Task=5')
# line, = ax.plot(cs, vP3T4I7K100, label='#CPU=3, #Task=7')
# line, = ax.plot(cs, vP3T4I6K100, label='#CPU=3, #Task=6')
# line, = ax.plot(cs, vP2T3I4K100, label='#CPU=2, #Task=4')
# line, = ax.plot(cs, vP3T4I5K100, label='#CPU=3, #Task=5')
ax.set_xlabel(r'c')
ax.set_ylabel('Work Stealing vs Optimal')




# line, = ax.plot(CS_k, P2T3I3, label='#CPU=2, #Thread=3, #Task=3')
# ax.fill_between(x, y_p2_t3_i2, y_p2_t3_i2_var, color=line.get_color(), alpha=.1)

# line, = ax.plot(CS_k, P3T3I2, label='#CPU=3, #Thread=3, #Task=2')
# ax.fill_between(x, y_p3_t3_i2, y_p3_t3_i2_var, color=line.get_color(), alpha=.1)

ax.legend()
fig.savefig('tasks.pdf')
# ax.set_xscale('symlog')

# %%
import plotly.graph_objs as go

fig = go.Figure([
    go.Scatter(
        x=x,
        y=y_p2_t3_i2,
        line=dict(color='rgb(0,100,80)'),
        mode='lines'
    ),
    go.Scatter(
        x=x+x[::-1], # x, then x reversed
        y=y_p2_t3_i2_var+y_p2_t3_i2[::-1], # upper, then lower reversed
        fill='toself',
        fillcolor='rgba(0,100,80,0.2)',
        line=dict(color='rgba(255,255,255,0)'),
        hoverinfo="skip",
        showlegend=False
    )
])
fig
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/ver/ver/lib/python3.8/site-packages/IPython/core/formatters.py:921, in IPythonDisplayFormatter.__call__(self, obj)
#     919 method = get_real_method(obj, self.print_method)
#     920 if method is not None:
# --> 921     method()
#     922     return True
#
# File ~/ver/ver/lib/python3.8/site-packages/plotly/basedatatypes.py:842, in BaseFigure._ipython_display_(self)
#     839 import plotly.io as pio
#     841 if pio.renderers.render_on_display and pio.renderers.default:
# --> 842     pio.show(self)
#     843 else:
#     844     print(repr(self))
#
# File ~/ver/ver/lib/python3.8/site-packages/plotly/io/_renderers.py:396, in show(fig, renderer, validate, **kwargs)
#     391         raise ValueError(
#     392             "Mime type rendering requires ipython but it is not installed"
#     393         )
# ...
